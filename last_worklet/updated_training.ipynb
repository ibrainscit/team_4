# %%
import os
import joblib
import numpy as np
import pandas as pd
import cupy as cp
import xgboost as xgb
import re
from sklearn.model_selection import StratifiedKFold, train_test_split, cross_val_score
from sklearn.metrics import (
    accuracy_score, classification_report, roc_auc_score, log_loss,
    balanced_accuracy_score, cohen_kappa_score
)
from sklearn.preprocessing import MinMaxScaler, LabelEncoder
from sklearn.calibration import CalibratedClassifierCV

# Load and Preprocess Data
def load_and_preprocess(directory, label=None):
    data_frames = []
    for file in os.listdir(directory):
        if file.endswith(".csv"):
            df = pd.read_csv(os.path.join(directory, file))
            if label is not None:
                df["Label"] = label  # Assign class labels
            # Extract subject ID from filename (e.g., sub-88000489)
            match = re.search(r"(sub-\d+)", file)
            df["subject_id"] = match.group(1) if match else "unknown"
            data_frames.append(df)

    df = pd.concat(data_frames, ignore_index=True)
    
    # Encode categorical columns except subject_id
    for col in df.select_dtypes(include=['object']).columns:
        if col != "subject_id":
            df[col] = LabelEncoder().fit_transform(df[col])
    
    # Handle missing values ONLY for numeric columns
    numeric_cols = df.select_dtypes(include=[np.number]).columns
    df[numeric_cols] = df[numeric_cols].fillna(df[numeric_cols].median())

    return df


# Load Data
dataset_path_healthy = "/mnt/data/saikrishna/Team_4/preprocessed_data_new/healthy"
dataset_path_mdd = "/mnt/data/saikrishna/Team_4/preprocessed_data_new/mdd"

df_healthy = load_and_preprocess(dataset_path_healthy, label=0)
df_mdd = load_and_preprocess(dataset_path_mdd, label=1)

df = pd.concat([df_healthy, df_mdd], axis=0).reset_index(drop=True)

# Subject-level Split
unique_subjects = df["subject_id"].unique()
train_ids, test_ids = train_test_split(unique_subjects, test_size=0.2, random_state=42, stratify=None)
val_ids, test_ids = train_test_split(test_ids, test_size=0.5, random_state=42)

train_df = df[df["subject_id"].isin(train_ids)]
val_df = df[df["subject_id"].isin(val_ids)]
test_df = df[df["subject_id"].isin(test_ids)]

# Drop subject ID
X_train = train_df.drop(columns=["Label", "subject_id"]).values
y_train = train_df["Label"].values

original_feature_names = train_df.drop(columns=["Label", "subject_id"]).columns.tolist()
joblib.dump(original_feature_names, "original_feature_names.pkl")

X_val = val_df.drop(columns=["Label", "subject_id"]).values
y_val = val_df["Label"].values

X_test = test_df.drop(columns=["Label", "subject_id"]).values
y_test = test_df["Label"].values

# Scale data
scaler = MinMaxScaler(feature_range=(0, 100))
X_train_scaled = scaler.fit_transform(X_train)
X_val_scaled = scaler.transform(X_val)
X_test_scaled = scaler.transform(X_test)
joblib.dump(scaler, "best_xgb_scaler.pkl")

# Define XGBoost Model
xgb_model = xgb.XGBClassifier(
    objective="binary:logistic",
    tree_method="hist",
    device="cuda",
    eval_metric="logloss",
    learning_rate=0.005,
    max_depth=25,
    gamma=0.2,
    subsample=0.95,
    colsample_bytree=0.97,
    min_child_weight=1,
    reg_alpha=0.8,
    reg_lambda=3.0,
    n_estimators=6000,
    verbosity=1
)

# Calibrated Model
calibrated_model = CalibratedClassifierCV(estimator=xgb_model, method='sigmoid', cv=3)
calibrated_model.fit(X_train_scaled, y_train)
joblib.dump(calibrated_model, "best_xgb_calibrated_model.pkl")

# Cross-Validation (on train set)
cv = StratifiedKFold(n_splits=5, shuffle=True, random_state=100)
cv_scores = cross_val_score(xgb_model, X_train_scaled, y_train, cv=cv, scoring="accuracy")

# Train original model for evaluation
xgb_model.fit(X_train_scaled, y_train)
joblib.dump(xgb_model, "best_xgb_model.pkl")

# ✅ Transfer input to GPU using CuPy
X_val_gpu = cp.array(X_val_scaled)
val_preds = xgb_model.predict(X_val_gpu)
val_probs = xgb_model.predict_proba(X_val_gpu)[:, 1]


accuracy = accuracy_score(y_val, val_preds)
roc_auc = roc_auc_score(y_val, val_probs)
logloss_val = log_loss(y_val, val_probs)
balanced_acc = balanced_accuracy_score(y_val, val_preds)
kappa = cohen_kappa_score(y_val, val_preds)
report = classification_report(y_val, val_preds)

# Print Results
print(f"\nValidation Accuracy: {accuracy:.4f}")
print(f"Balanced Accuracy: {balanced_acc:.4f}")
print(f"Cohen's Kappa: {kappa:.4f}")
print(f"Log Loss: {logloss_val:.4f}")
print(f"ROC AUC Score: {roc_auc:.4f}")
print("\nClassification Report:\n", report)
print(f"Cross-Validation Accuracy Scores: {cv_scores}")
# Out:
# Validation Accuracy: 0.9167
# Balanced Accuracy: 0.9000
# Cohen's Kappa: 0.8235
# Log Loss: 0.4183
# ROC AUC Score: 0.8714
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.88      1.00      0.93        14
#            1       1.00      0.80      0.89        10
#
#     accuracy                           0.92        24
#    macro avg       0.94      0.90      0.91        24
# weighted avg       0.93      0.92      0.91        24
#
# Cross-Validation Accuracy Scores: [0.74285714 0.82857143 0.76470588 0.79411765 0.76470588]

# %% [markdown]
# # Training with multiple random states for mdd 0 to 80

# %%
import os
import joblib
import numpy as np
import pandas as pd
import cupy as cp
import xgboost as xgb
import re
from sklearn.model_selection import StratifiedKFold, train_test_split
from sklearn.metrics import (
    accuracy_score, classification_report, roc_auc_score, log_loss,
    balanced_accuracy_score, cohen_kappa_score
)
from sklearn.preprocessing import MinMaxScaler, LabelEncoder
from sklearn.calibration import CalibratedClassifierCV

# ------------------- Load and Preprocess -------------------
def load_and_preprocess(directory, label=None):
    data_frames = []
    for file in os.listdir(directory):
        if file.endswith(".csv"):
            df = pd.read_csv(os.path.join(directory, file))
            if label is not None:
                df["Label"] = label
            match = re.search(r"(sub-\d+)", file)
            df["subject_id"] = match.group(1) if match else "unknown"
            data_frames.append(df)

    df = pd.concat(data_frames, ignore_index=True)
    
    for col in df.select_dtypes(include=['object']).columns:
        if col != "subject_id":
            df[col] = LabelEncoder().fit_transform(df[col])
    
    numeric_cols = df.select_dtypes(include=[np.number]).columns
    df[numeric_cols] = df[numeric_cols].fillna(df[numeric_cols].median())

    return df

# ------------------- Data Paths -------------------
dataset_path_healthy = "/mnt/data/saikrishna/Team_4/preprocessed_data_new/healthy"
dataset_path_mdd = "/mnt/data/saikrishna/Team_4/preprocessed_data_new/mdd"

df_healthy = load_and_preprocess(dataset_path_healthy, label=0)
df_mdd = load_and_preprocess(dataset_path_mdd, label=1)

df = pd.concat([df_healthy, df_mdd], axis=0).reset_index(drop=True)

# ------------------- Random States to Evaluate -------------------
random_states = list(range(1, 11)) + [42, 100, 123, 2021, 7]
results = []
# ------------------- Loop Over Random States -------------------
for state in random_states:
    print(f"\n================ Random State: {state} ================\n")
    
    unique_subjects = df["subject_id"].unique()
    train_ids, test_ids = train_test_split(unique_subjects, test_size=0.2, random_state=state, stratify=None)
    val_ids, test_ids = train_test_split(test_ids, test_size=0.5, random_state=state)
    
    train_df = df[df["subject_id"].isin(train_ids)]
    val_df = df[df["subject_id"].isin(val_ids)]
    
    X_train = train_df.drop(columns=["Label", "subject_id"]).values
    y_train = train_df["Label"].values
    X_val = val_df.drop(columns=["Label", "subject_id"]).values
    y_val = val_df["Label"].values

    # Scaling
    scaler = MinMaxScaler(feature_range=(0, 100))
    X_train_scaled = scaler.fit_transform(X_train)
    X_val_scaled = scaler.transform(X_val)

    # Define XGBoost Model
    xgb_model = xgb.XGBClassifier(
        objective="binary:logistic",
        tree_method="hist",
        device="cuda",
        eval_metric="logloss",
        learning_rate=0.005,
        max_depth=25,
        gamma=0.2,
        subsample=0.95,
        colsample_bytree=0.97,
        min_child_weight=1,
        reg_alpha=0.8,
        reg_lambda=3.0,
        n_estimators=6000,
        verbosity=0
    )

    # Calibrated model
    calibrated_model = CalibratedClassifierCV(estimator=xgb_model, method='sigmoid', cv=3)
    calibrated_model.fit(X_train_scaled, y_train)

    # Train original model (not calibrated) for validation evaluation
    xgb_model.fit(X_train_scaled, y_train)

    # Validation
    X_val_gpu = cp.array(X_val_scaled)
    val_preds = xgb_model.predict(X_val_gpu)
    val_probs = xgb_model.predict_proba(X_val_gpu)[:, 1]

    accuracy = accuracy_score(y_val, val_preds)
    roc_auc = roc_auc_score(y_val, val_probs)
    logloss_val = log_loss(y_val, val_probs)
    balanced_acc = balanced_accuracy_score(y_val, val_preds)
    kappa = cohen_kappa_score(y_val, val_preds)
    report = classification_report(y_val, val_preds)

        # Store results
    results.append({
        "random_state": state,
        "accuracy": accuracy,
        "balanced_accuracy": balanced_acc,
        "kappa": kappa,
        "log_loss": logloss_val,
        "roc_auc": roc_auc
    })

    # Print results
    print(f"Validation Accuracy: {accuracy:.4f}")
    print(f"Balanced Accuracy: {balanced_acc:.4f}")
    print(f"Cohen's Kappa: {kappa:.4f}")
    print(f"Log Loss: {logloss_val:.4f}")
    print(f"ROC AUC Score: {roc_auc:.4f}")
    print("\nClassification Report:\n", report)

best_result = max(results, key=lambda x: x["accuracy"])
print("\n================== BEST RANDOM STATE ==================\n")
print(f"Best Random State: {best_result['random_state']}")
print(f"Validation Accuracy: {best_result['accuracy']:.4f}")
print(f"Balanced Accuracy: {best_result['balanced_accuracy']:.4f}")
print(f"Cohen's Kappa: {best_result['kappa']:.4f}")
print(f"Log Loss: {best_result['log_loss']:.4f}")
print(f"ROC AUC Score: {best_result['roc_auc']:.4f}")
print("\n========================================================\n")

results_df = pd.DataFrame(results)
results_df.to_csv("classification_80_mdd.csv", index=False)
# Out:
# ================ Random State: 1 ================
#
# Validation Accuracy: 0.7200
# Balanced Accuracy: 0.8158
# Cohen's Kappa: 0.4514
# Log Loss: 0.5685
# ROC AUC Score: 0.9474
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.46      1.00      0.63         6
#            1       1.00      0.63      0.77        19
#
#     accuracy                           0.72        25
#    macro avg       0.73      0.82      0.70        25
# weighted avg       0.87      0.72      0.74        25
#
#
# ================ Random State: 2 ================
#
# Validation Accuracy: 0.5500
# Balanced Accuracy: 0.5500
# Cohen's Kappa: 0.1000
# Log Loss: 0.8575
# ROC AUC Score: 0.4400
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.67      0.20      0.31        10
#            1       0.53      0.90      0.67        10
#
#     accuracy                           0.55        20
#    macro avg       0.60      0.55      0.49        20
# weighted avg       0.60      0.55      0.49        20
#
#
# ================ Random State: 3 ================
#
# Validation Accuracy: 0.3182
# Balanced Accuracy: 0.3182
# Cohen's Kappa: -0.3636
# Log Loss: 1.2180
# ROC AUC Score: 0.3471
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.30      0.27      0.29        11
#            1       0.33      0.36      0.35        11
#
#     accuracy                           0.32        22
#    macro avg       0.32      0.32      0.32        22
# weighted avg       0.32      0.32      0.32        22
#
#
# ================ Random State: 4 ================
#
# Validation Accuracy: 0.6522
# Balanced Accuracy: 0.6151
# Cohen's Kappa: 0.2397
# Log Loss: 0.7733
# ROC AUC Score: 0.6429
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.57      0.44      0.50         9
#            1       0.69      0.79      0.73        14
#
#     accuracy                           0.65        23
#    macro avg       0.63      0.62      0.62        23
# weighted avg       0.64      0.65      0.64        23
#
#
# ================ Random State: 5 ================
#
# Validation Accuracy: 0.8261
# Balanced Accuracy: 0.8175
# Cohen's Kappa: 0.6349
# Log Loss: 0.4470
# ROC AUC Score: 0.8889
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.78      0.78      0.78         9
#            1       0.86      0.86      0.86        14
#
#     accuracy                           0.83        23
#    macro avg       0.82      0.82      0.82        23
# weighted avg       0.83      0.83      0.83        23
#
#
# ================ Random State: 6 ================
#
# Validation Accuracy: 0.6667
# Balanced Accuracy: 0.6944
# Cohen's Kappa: 0.3636
# Log Loss: 0.7011
# ROC AUC Score: 0.7315
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.86      0.50      0.63        12
#            1       0.57      0.89      0.70         9
#
#     accuracy                           0.67        21
#    macro avg       0.71      0.69      0.66        21
# weighted avg       0.73      0.67      0.66        21
#
#
# ================ Random State: 7 ================
#
# Validation Accuracy: 0.4444
# Balanced Accuracy: 0.3636
# Cohen's Kappa: -0.3043
# Log Loss: 0.6561
# ROC AUC Score: 0.6104
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00         7
#            1       0.53      0.73      0.62        11
#
#     accuracy                           0.44        18
#    macro avg       0.27      0.36      0.31        18
# weighted avg       0.33      0.44      0.38        18
#
#
# ================ Random State: 8 ================
#
# Validation Accuracy: 0.8750
# Balanced Accuracy: 0.8500
# Cohen's Kappa: 0.7313
# Log Loss: 0.4020
# ROC AUC Score: 0.9571
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       1.00      0.70      0.82        10
#            1       0.82      1.00      0.90        14
#
#     accuracy                           0.88        24
#    macro avg       0.91      0.85      0.86        24
# weighted avg       0.90      0.88      0.87        24
#
#
# ================ Random State: 9 ================
#
# Validation Accuracy: 0.7273
# Balanced Accuracy: 0.6786
# Cohen's Kappa: 0.3774
# Log Loss: 0.5691
# ROC AUC Score: 0.7321
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.67      0.50      0.57         8
#            1       0.75      0.86      0.80        14
#
#     accuracy                           0.73        22
#    macro avg       0.71      0.68      0.69        22
# weighted avg       0.72      0.73      0.72        22
#
#
# ================ Random State: 10 ================
#
# Validation Accuracy: 0.6538
# Balanced Accuracy: 0.6607
# Cohen's Kappa: 0.3158
# Log Loss: 0.5437
# ROC AUC Score: 0.8214
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.73      0.57      0.64        14
#            1       0.60      0.75      0.67        12
#
#     accuracy                           0.65        26
#    macro avg       0.66      0.66      0.65        26
# weighted avg       0.67      0.65      0.65        26
#
#
# ================ Random State: 42 ================
#
# Validation Accuracy: 0.9167
# Balanced Accuracy: 0.9000
# Cohen's Kappa: 0.8235
# Log Loss: 0.4183
# ROC AUC Score: 0.8714
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.88      1.00      0.93        14
#            1       1.00      0.80      0.89        10
#
#     accuracy                           0.92        24
#    macro avg       0.94      0.90      0.91        24
# weighted avg       0.93      0.92      0.91        24
#
#
# ================ Random State: 100 ================
#
# Validation Accuracy: 0.6667
# Balanced Accuracy: 0.6545
# Cohen's Kappa: 0.3163
# Log Loss: 0.5773
# ROC AUC Score: 0.8182
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.80      0.40      0.53        10
#            1       0.62      0.91      0.74        11
#
#     accuracy                           0.67        21
#    macro avg       0.71      0.65      0.64        21
# weighted avg       0.71      0.67      0.64        21
#
#
# ================ Random State: 123 ================
#
# Validation Accuracy: 0.5000
# Balanced Accuracy: 0.4048
# Cohen's Kappa: -0.1980
# Log Loss: 1.0350
# ROC AUC Score: 0.2762
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.17      0.14      0.15         7
#            1       0.62      0.67      0.65        15
#
#     accuracy                           0.50        22
#    macro avg       0.40      0.40      0.40        22
# weighted avg       0.48      0.50      0.49        22
#
#
# ================ Random State: 2021 ================
#
# Validation Accuracy: 0.6842
# Balanced Accuracy: 0.5714
# Cohen's Kappa: 0.1739
# Log Loss: 0.5057
# ROC AUC Score: 0.8929
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       1.00      0.14      0.25         7
#            1       0.67      1.00      0.80        12
#
#     accuracy                           0.68        19
#    macro avg       0.83      0.57      0.53        19
# weighted avg       0.79      0.68      0.60        19
#
#
# ================ Random State: 7 ================
#
# Validation Accuracy: 0.4444
# Balanced Accuracy: 0.3636
# Cohen's Kappa: -0.3043
# Log Loss: 0.6561
# ROC AUC Score: 0.6104
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00         7
#            1       0.53      0.73      0.62        11
#
#     accuracy                           0.44        18
#    macro avg       0.27      0.36      0.31        18
# weighted avg       0.33      0.44      0.38        18
#
#
# ================== BEST RANDOM STATE ==================
#
# Best Random State: 42
# Validation Accuracy: 0.9167
# Balanced Accuracy: 0.9000
# Cohen's Kappa: 0.8235
# Log Loss: 0.4183
# ROC AUC Score: 0.8714
#
# ========================================================

# %%
import os
import joblib
import numpy as np
import pandas as pd
import cupy as cp
import xgboost as xgb
import re
from sklearn.model_selection import StratifiedKFold, train_test_split
from sklearn.metrics import (
    accuracy_score, classification_report, roc_auc_score, log_loss,
    balanced_accuracy_score, cohen_kappa_score
)
from sklearn.preprocessing import MinMaxScaler, LabelEncoder
from sklearn.calibration import CalibratedClassifierCV

# ------------------- Load and Preprocess -------------------
def load_and_preprocess(directory, label=None):
    data_frames = []
    for file in os.listdir(directory):
        if file.endswith(".csv"):
            df = pd.read_csv(os.path.join(directory, file))
            if label is not None:
                df["Label"] = label
            match = re.search(r"(sub-\d+)", file)
            df["subject_id"] = match.group(1) if match else "unknown"
            data_frames.append(df)

    df = pd.concat(data_frames, ignore_index=True)
    
    for col in df.select_dtypes(include=['object']).columns:
        if col != "subject_id":
            df[col] = LabelEncoder().fit_transform(df[col])
    
    numeric_cols = df.select_dtypes(include=[np.number]).columns
    df[numeric_cols] = df[numeric_cols].fillna(df[numeric_cols].median())

    return df

# ------------------- Data Paths -------------------
dataset_path_healthy = "/mnt/data/saikrishna/Team_4/preprocessed_data_new/healthy"
dataset_path_mdd = "/mnt/data/saikrishna/Team_4/preprocessed_data_new/mdd2"

df_healthy = load_and_preprocess(dataset_path_healthy, label=0)
df_mdd = load_and_preprocess(dataset_path_mdd, label=1)

df = pd.concat([df_healthy, df_mdd], axis=0).reset_index(drop=True)

# ------------------- Random States to Evaluate -------------------
random_states = list(range(1, 11)) + [42, 100, 123, 2021, 7]
results = []
# ------------------- Loop Over Random States -------------------
for state in random_states:
    print(f"\n================ Random State: {state} ================\n")
    
    unique_subjects = df["subject_id"].unique()
    train_ids, test_ids = train_test_split(unique_subjects, test_size=0.2, random_state=state, stratify=None)
    val_ids, test_ids = train_test_split(test_ids, test_size=0.5, random_state=state)
    
    train_df = df[df["subject_id"].isin(train_ids)]
    val_df = df[df["subject_id"].isin(val_ids)]
    
    X_train = train_df.drop(columns=["Label", "subject_id"]).values
    y_train = train_df["Label"].values
    X_val = val_df.drop(columns=["Label", "subject_id"]).values
    y_val = val_df["Label"].values

    # Scaling
    scaler = MinMaxScaler(feature_range=(0, 100))
    X_train_scaled = scaler.fit_transform(X_train)
    X_val_scaled = scaler.transform(X_val)

    # Define XGBoost Model
    xgb_model = xgb.XGBClassifier(
        objective="binary:logistic",
        tree_method="hist",
        device="cuda",
        eval_metric="logloss",
        learning_rate=0.005,
        max_depth=25,
        gamma=0.2,
        subsample=0.95,
        colsample_bytree=0.97,
        min_child_weight=1,
        reg_alpha=0.8,
        reg_lambda=3.0,
        n_estimators=6000,
        verbosity=0
    )

    # Calibrated model
    calibrated_model = CalibratedClassifierCV(estimator=xgb_model, method='sigmoid', cv=3)
    calibrated_model.fit(X_train_scaled, y_train)

    # Train original model (not calibrated) for validation evaluation
    xgb_model.fit(X_train_scaled, y_train)

    # Validation
    X_val_gpu = cp.array(X_val_scaled)
    val_preds = xgb_model.predict(X_val_gpu)
    val_probs = xgb_model.predict_proba(X_val_gpu)[:, 1]

    accuracy = accuracy_score(y_val, val_preds)
    roc_auc = roc_auc_score(y_val, val_probs)
    logloss_val = log_loss(y_val, val_probs)
    balanced_acc = balanced_accuracy_score(y_val, val_preds)
    kappa = cohen_kappa_score(y_val, val_preds)
    report = classification_report(y_val, val_preds)

        # Store results
    results.append({
        "random_state": state,
        "accuracy": accuracy,
        "balanced_accuracy": balanced_acc,
        "kappa": kappa,
        "log_loss": logloss_val,
        "roc_auc": roc_auc
    })

    # Print results
    print(f"Validation Accuracy: {accuracy:.4f}")
    print(f"Balanced Accuracy: {balanced_acc:.4f}")
    print(f"Cohen's Kappa: {kappa:.4f}")
    print(f"Log Loss: {logloss_val:.4f}")
    print(f"ROC AUC Score: {roc_auc:.4f}")
    print("\nClassification Report:\n", report)

best_result = max(results, key=lambda x: x["accuracy"])
print("\n================== BEST RANDOM STATE ==================\n")
print(f"Best Random State: {best_result['random_state']}")
print(f"Validation Accuracy: {best_result['accuracy']:.4f}")
print(f"Balanced Accuracy: {best_result['balanced_accuracy']:.4f}")
print(f"Cohen's Kappa: {best_result['kappa']:.4f}")
print(f"Log Loss: {best_result['log_loss']:.4f}")
print(f"ROC AUC Score: {best_result['roc_auc']:.4f}")
print("\n========================================================\n")
results_df = pd.DataFrame(results)
results_df.to_csv("random_state_results_80_mdd2.csv", index=False)
# Out:
# ================ Random State: 1 ================
#
# Validation Accuracy: 0.7143
# Balanced Accuracy: 0.6944
# Cohen's Kappa: 0.4000
# Log Loss: 0.5398
# ROC AUC Score: 0.8148
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.71      0.56      0.62         9
#            1       0.71      0.83      0.77        12
#
#     accuracy                           0.71        21
#    macro avg       0.71      0.69      0.70        21
# weighted avg       0.71      0.71      0.71        21
#
#
# ================ Random State: 2 ================
#
# Validation Accuracy: 0.4286
# Balanced Accuracy: 0.5000
# Cohen's Kappa: 0.0000
# Log Loss: 0.9344
# ROC AUC Score: 0.6111
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.71      0.33      0.45        15
#            1       0.29      0.67      0.40         6
#
#     accuracy                           0.43        21
#    macro avg       0.50      0.50      0.43        21
# weighted avg       0.59      0.43      0.44        21
#
#
# ================ Random State: 3 ================
#
# Validation Accuracy: 0.6190
# Balanced Accuracy: 0.5833
# Cohen's Kappa: 0.1765
# Log Loss: 0.7031
# ROC AUC Score: 0.7130
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.60      0.33      0.43         9
#            1       0.62      0.83      0.71        12
#
#     accuracy                           0.62        21
#    macro avg       0.61      0.58      0.57        21
# weighted avg       0.61      0.62      0.59        21
#
#
# ================ Random State: 4 ================
#
# Validation Accuracy: 0.8333
# Balanced Accuracy: 0.7812
# Cohen's Kappa: 0.6000
# Log Loss: 0.3812
# ROC AUC Score: 0.9062
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.83      0.62      0.71         8
#            1       0.83      0.94      0.88        16
#
#     accuracy                           0.83        24
#    macro avg       0.83      0.78      0.80        24
# weighted avg       0.83      0.83      0.83        24
#
#
# ================ Random State: 5 ================
#
# Validation Accuracy: 0.5769
# Balanced Accuracy: 0.5250
# Cohen's Kappa: 0.0530
# Log Loss: 0.6069
# ROC AUC Score: 0.7438
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.43      0.30      0.35        10
#            1       0.63      0.75      0.69        16
#
#     accuracy                           0.58        26
#    macro avg       0.53      0.53      0.52        26
# weighted avg       0.55      0.58      0.56        26
#
#
# ================ Random State: 6 ================
#
# Validation Accuracy: 0.6667
# Balanced Accuracy: 0.6667
# Cohen's Kappa: 0.3288
# Log Loss: 0.6404
# ROC AUC Score: 0.6944
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.60      0.67      0.63         9
#            1       0.73      0.67      0.70        12
#
#     accuracy                           0.67        21
#    macro avg       0.66      0.67      0.66        21
# weighted avg       0.67      0.67      0.67        21
#
#
# ================ Random State: 7 ================
#
# Validation Accuracy: 0.5000
# Balanced Accuracy: 0.4750
# Cohen's Kappa: -0.0519
# Log Loss: 0.6442
# ROC AUC Score: 0.6875
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.40      0.25      0.31         8
#            1       0.54      0.70      0.61        10
#
#     accuracy                           0.50        18
#    macro avg       0.47      0.47      0.46        18
# weighted avg       0.48      0.50      0.47        18
#
#
# ================ Random State: 8 ================
#
# Validation Accuracy: 0.6087
# Balanced Accuracy: 0.5198
# Cohen's Kappa: 0.0461
# Log Loss: 0.6187
# ROC AUC Score: 0.7540
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.50      0.11      0.18         9
#            1       0.62      0.93      0.74        14
#
#     accuracy                           0.61        23
#    macro avg       0.56      0.52      0.46        23
# weighted avg       0.57      0.61      0.52        23
#
#
# ================ Random State: 9 ================
#
# Validation Accuracy: 0.6364
# Balanced Accuracy: 0.5417
# Cohen's Kappa: 0.0833
# Log Loss: 0.7907
# ROC AUC Score: 0.5833
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.33      0.33      0.33         6
#            1       0.75      0.75      0.75        16
#
#     accuracy                           0.64        22
#    macro avg       0.54      0.54      0.54        22
# weighted avg       0.64      0.64      0.64        22
#
#
# ================ Random State: 10 ================
#
# Validation Accuracy: 0.9091
# Balanced Accuracy: 0.8750
# Cohen's Kappa: 0.7925
# Log Loss: 0.4277
# ROC AUC Score: 0.8125
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       1.00      0.75      0.86         8
#            1       0.88      1.00      0.93        14
#
#     accuracy                           0.91        22
#    macro avg       0.94      0.88      0.90        22
# weighted avg       0.92      0.91      0.91        22
#
#
# ================ Random State: 42 ================
#
# Validation Accuracy: 0.8000
# Balanced Accuracy: 0.8333
# Cohen's Kappa: 0.6154
# Log Loss: 0.4674
# ROC AUC Score: 0.9067
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       1.00      0.67      0.80        15
#            1       0.67      1.00      0.80        10
#
#     accuracy                           0.80        25
#    macro avg       0.83      0.83      0.80        25
# weighted avg       0.87      0.80      0.80        25
#
#
# ================ Random State: 100 ================
#
# Validation Accuracy: 0.5652
# Balanced Accuracy: 0.4866
# Cohen's Kappa: -0.0268
# Log Loss: 0.8383
# ROC AUC Score: 0.5000
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.29      0.29      0.29         7
#            1       0.69      0.69      0.69        16
#
#     accuracy                           0.57        23
#    macro avg       0.49      0.49      0.49        23
# weighted avg       0.57      0.57      0.57        23
#
#
# ================ Random State: 123 ================
#
# Validation Accuracy: 0.7727
# Balanced Accuracy: 0.7583
# Cohen's Kappa: 0.5299
# Log Loss: 0.6759
# ROC AUC Score: 0.6500
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.86      0.60      0.71        10
#            1       0.73      0.92      0.81        12
#
#     accuracy                           0.77        22
#    macro avg       0.80      0.76      0.76        22
# weighted avg       0.79      0.77      0.77        22
#
#
# ================ Random State: 2021 ================
#
# Validation Accuracy: 0.6087
# Balanced Accuracy: 0.6190
# Cohen's Kappa: 0.2247
# Log Loss: 0.8633
# ROC AUC Score: 0.6032
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.50      0.67      0.57         9
#            1       0.73      0.57      0.64        14
#
#     accuracy                           0.61        23
#    macro avg       0.61      0.62      0.61        23
# weighted avg       0.64      0.61      0.61        23
#
#
# ================ Random State: 7 ================
#
# Validation Accuracy: 0.5000
# Balanced Accuracy: 0.4750
# Cohen's Kappa: -0.0519
# Log Loss: 0.6442
# ROC AUC Score: 0.6875
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.40      0.25      0.31         8
#            1       0.54      0.70      0.61        10
#
#     accuracy                           0.50        18
#    macro avg       0.47      0.47      0.46        18
# weighted avg       0.48      0.50      0.47        18
#
#
# ================== BEST RANDOM STATE ==================
#
# Best Random State: 10
# Validation Accuracy: 0.9091
# Balanced Accuracy: 0.8750
# Cohen's Kappa: 0.7925
# Log Loss: 0.4277
# ROC AUC Score: 0.8125
#
# ========================================================

# %%
import os
import joblib
import numpy as np
import pandas as pd
import cupy as cp
import xgboost as xgb 
import re
from sklearn.model_selection import StratifiedKFold, train_test_split
from sklearn.metrics import (
    accuracy_score, classification_report, roc_auc_score, log_loss,
    balanced_accuracy_score, cohen_kappa_score
)
from sklearn.preprocessing import MinMaxScaler, LabelEncoder
from sklearn.calibration import CalibratedClassifierCV

# ------------------- Load and Preprocess -------------------
def load_and_preprocess(directory, label=None):
    data_frames = []
    for file in os.listdir(directory):
        if file.endswith(".csv"):
            df = pd.read_csv(os.path.join(directory, file))
            if label is not None:
                df["Label"] = label
            match = re.search(r"(sub-\d+)", file)
            df["subject_id"] = match.group(1) if match else "unknown"
            data_frames.append(df)

    df = pd.concat(data_frames, ignore_index=True)
    
    for col in df.select_dtypes(include=['object']).columns:
        if col != "subject_id":
            df[col] = LabelEncoder().fit_transform(df[col])
    
    numeric_cols = df.select_dtypes(include=[np.number]).columns
    df[numeric_cols] = df[numeric_cols].fillna(df[numeric_cols].median())

    return df

# ------------------- Data Paths -------------------
dataset_path_healthy = "/mnt/data/saikrishna/Team_4/preprocessed_data_new/healthy"
dataset_path_mdd = "/mnt/data/saikrishna/Team_4/preprocessed_data_new/mdd3"

df_healthy = load_and_preprocess(dataset_path_healthy, label=0)
df_mdd = load_and_preprocess(dataset_path_mdd, label=1)

df = pd.concat([df_healthy, df_mdd], axis=0).reset_index(drop=True)

# ------------------- Random States to Evaluate -------------------
random_states = list(range(1, 11)) + [42, 100, 123, 2021, 7]
results = []
# ------------------- Loop Over Random States -------------------
for state in random_states:
    print(f"\n================ Random State: {state} ================\n")
    
    unique_subjects = df["subject_id"].unique()
    train_ids, test_ids = train_test_split(unique_subjects, test_size=0.2, random_state=state, stratify=None)
    val_ids, test_ids = train_test_split(test_ids, test_size=0.5, random_state=state)
    
    train_df = df[df["subject_id"].isin(train_ids)]
    val_df = df[df["subject_id"].isin(val_ids)]
    
    X_train = train_df.drop(columns=["Label", "subject_id"]).values
    y_train = train_df["Label"].values
    X_val = val_df.drop(columns=["Label", "subject_id"]).values
    y_val = val_df["Label"].values

    # Scaling
    scaler = MinMaxScaler(feature_range=(0, 100))
    X_train_scaled = scaler.fit_transform(X_train)
    X_val_scaled = scaler.transform(X_val)

    # Define XGBoost Model
    xgb_model = xgb.XGBClassifier(
        objective="binary:logistic",
        tree_method="hist",
        device="cuda",
        eval_metric="logloss",
        learning_rate=0.005,
        max_depth=25,
        gamma=0.2,
        subsample=0.95,
        colsample_bytree=0.97,
        min_child_weight=1,
        reg_alpha=0.8,
        reg_lambda=3.0,
        n_estimators=6000,
        verbosity=0
    )

    # Calibrated model
    calibrated_model = CalibratedClassifierCV(estimator=xgb_model, method='sigmoid', cv=3)
    calibrated_model.fit(X_train_scaled, y_train)

    # Train original model (not calibrated) for validation evaluation
    xgb_model.fit(X_train_scaled, y_train)

    # Validation
    X_val_gpu = cp.array(X_val_scaled)
    val_preds = xgb_model.predict(X_val_gpu)
    val_probs = xgb_model.predict_proba(X_val_gpu)[:, 1]

    accuracy = accuracy_score(y_val, val_preds)
    roc_auc = roc_auc_score(y_val, val_probs)
    logloss_val = log_loss(y_val, val_probs)
    balanced_acc = balanced_accuracy_score(y_val, val_preds)
    kappa = cohen_kappa_score(y_val, val_preds)
    report = classification_report(y_val, val_preds)

        # Store results
    results.append({
        "random_state": state,
        "accuracy": accuracy,
        "balanced_accuracy": balanced_acc,
        "kappa": kappa,
        "log_loss": logloss_val,
        "roc_auc": roc_auc
    })

    # Print results
    print(f"Validation Accuracy: {accuracy:.4f}")
    print(f"Balanced Accuracy: {balanced_acc:.4f}")
    print(f"Cohen's Kappa: {kappa:.4f}")
    print(f"Log Loss: {logloss_val:.4f}")
    print(f"ROC AUC Score: {roc_auc:.4f}")
    print("\nClassification Report:\n", report)

best_result = max(results, key=lambda x: x["accuracy"])
print("\n================== BEST RANDOM STATE ==================\n")
print(f"Best Random State: {best_result['random_state']}")
print(f"Validation Accuracy: {best_result['accuracy']:.4f}")
print(f"Balanced Accuracy: {best_result['balanced_accuracy']:.4f}")
print(f"Cohen's Kappa: {best_result['kappa']:.4f}")
print(f"Log Loss: {best_result['log_loss']:.4f}")
print(f"ROC AUC Score: {best_result['roc_auc']:.4f}")
print("\n========================================================\n")
results_df = pd.DataFrame(results)
results_df.to_csv("random_state_results_mdd3_80.csv", index=False)
# Out:
# ================ Random State: 1 ================
# Validation Accuracy: 0.5769
# Balanced Accuracy: 0.6083
# Cohen's Kappa: 0.1538
# Log Loss: 0.6227
# ROC AUC Score: 0.7250
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.31      0.67      0.42         6
#            1       0.85      0.55      0.67        20
#
#     accuracy                           0.58        26
#    macro avg       0.58      0.61      0.54        26
# weighted avg       0.72      0.58      0.61        26
#
#
# ================ Random State: 2 ================
#
# Validation Accuracy: 0.5417
# Balanced Accuracy: 0.4786
# Cohen's Kappa: -0.0476
# Log Loss: 0.9496
# ROC AUC Score: 0.5714
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.33      0.10      0.15        10
#            1       0.57      0.86      0.69        14
#
#     accuracy                           0.54        24
#    macro avg       0.45      0.48      0.42        24
# weighted avg       0.47      0.54      0.46        24
#
#
# ================ Random State: 3 ================
#
# Validation Accuracy: 0.6250
# Balanced Accuracy: 0.6250
# Cohen's Kappa: 0.2500
# Log Loss: 0.6049
# ROC AUC Score: 0.8194
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.71      0.42      0.53        12
#            1       0.59      0.83      0.69        12
#
#     accuracy                           0.62        24
#    macro avg       0.65      0.62      0.61        24
# weighted avg       0.65      0.62      0.61        24
#
#
# ================ Random State: 4 ================
#
# Validation Accuracy: 0.3913
# Balanced Accuracy: 0.5882
# Cohen's Kappa: 0.1006
# Log Loss: 1.2175
# ROC AUC Score: 0.7059
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       1.00      0.18      0.30        17
#            1       0.30      1.00      0.46         6
#
#     accuracy                           0.39        23
#    macro avg       0.65      0.59      0.38        23
# weighted avg       0.82      0.39      0.34        23
#
#
# ================ Random State: 5 ================
#
# Validation Accuracy: 0.5833
# Balanced Accuracy: 0.5000
# Cohen's Kappa: 0.0000
# Log Loss: 0.7165
# ROC AUC Score: 0.6953
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.33      0.25      0.29         8
#            1       0.67      0.75      0.71        16
#
#     accuracy                           0.58        24
#    macro avg       0.50      0.50      0.50        24
# weighted avg       0.56      0.58      0.57        24
#
#
# ================ Random State: 6 ================
#
# Validation Accuracy: 0.5652
# Balanced Accuracy: 0.5238
# Cohen's Kappa: 0.0496
# Log Loss: 0.7013
# ROC AUC Score: 0.6270
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.43      0.33      0.38         9
#            1       0.62      0.71      0.67        14
#
#     accuracy                           0.57        23
#    macro avg       0.53      0.52      0.52        23
# weighted avg       0.55      0.57      0.55        23
#
#
# ================ Random State: 7 ================
#
# Validation Accuracy: 0.7826
# Balanced Accuracy: 0.6830
# Cohen's Kappa: 0.4162
# Log Loss: 0.4576
# ROC AUC Score: 0.8214
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.75      0.43      0.55         7
#            1       0.79      0.94      0.86        16
#
#     accuracy                           0.78        23
#    macro avg       0.77      0.68      0.70        23
# weighted avg       0.78      0.78      0.76        23
#
#
# ================ Random State: 8 ================
#
# Validation Accuracy: 1.0000
# Balanced Accuracy: 1.0000
# Cohen's Kappa: 1.0000
# Log Loss: 0.1567
# ROC AUC Score: 1.0000
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00         6
#            1       1.00      1.00      1.00        20
#
#     accuracy                           1.00        26
#    macro avg       1.00      1.00      1.00        26
# weighted avg       1.00      1.00      1.00        26
#
#
# ================ Random State: 9 ================
#
# Validation Accuracy: 0.7083
# Balanced Accuracy: 0.6786
# Cohen's Kappa: 0.3731
# Log Loss: 0.4215
# ROC AUC Score: 0.9071
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.71      0.50      0.59        10
#            1       0.71      0.86      0.77        14
#
#     accuracy                           0.71        24
#    macro avg       0.71      0.68      0.68        24
# weighted avg       0.71      0.71      0.70        24
#
#
# ================ Random State: 10 ================
#
# Validation Accuracy: 0.7200
# Balanced Accuracy: 0.7083
# Cohen's Kappa: 0.4068
# Log Loss: 0.5277
# ROC AUC Score: 0.7986
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.60      0.67      0.63         9
#            1       0.80      0.75      0.77        16
#
#     accuracy                           0.72        25
#    macro avg       0.70      0.71      0.70        25
# weighted avg       0.73      0.72      0.72        25
#
#
# ================ Random State: 42 ================
#
# Validation Accuracy: 0.6000
# Balanced Accuracy: 0.5649
# Cohen's Kappa: 0.1379
# Log Loss: 0.6377
# ROC AUC Score: 0.7403
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.60      0.27      0.38        11
#            1       0.60      0.86      0.71        14
#
#     accuracy                           0.60        25
#    macro avg       0.60      0.56      0.54        25
# weighted avg       0.60      0.60      0.56        25
#
#
# ================ Random State: 100 ================
#
# Validation Accuracy: 0.6000
# Balanced Accuracy: 0.4167
# Cohen's Kappa: -0.2019
# Log Loss: 0.8459
# ROC AUC Score: 0.5238
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00         7
#            1       0.68      0.83      0.75        18
#
#     accuracy                           0.60        25
#    macro avg       0.34      0.42      0.38        25
# weighted avg       0.49      0.60      0.54        25
#
#
# ================ Random State: 123 ================
#
# Validation Accuracy: 0.6400
# Balanced Accuracy: 0.6538
# Cohen's Kappa: 0.2991
# Log Loss: 1.0754
# ROC AUC Score: 0.5833
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       1.00      0.31      0.47        13
#            1       0.57      1.00      0.73        12
#
#     accuracy                           0.64        25
#    macro avg       0.79      0.65      0.60        25
# weighted avg       0.79      0.64      0.59        25
#
#
# ================ Random State: 2021 ================
#
# Validation Accuracy: 0.5417
# Balanced Accuracy: 0.4929
# Cohen's Kappa: -0.0154
# Log Loss: 0.7012
# ROC AUC Score: 0.6857
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.40      0.20      0.27        10
#            1       0.58      0.79      0.67        14
#
#     accuracy                           0.54        24
#    macro avg       0.49      0.49      0.47        24
# weighted avg       0.50      0.54      0.50        24
#
#
# ================ Random State: 7 ================
#
# Validation Accuracy: 0.7826
# Balanced Accuracy: 0.6830
# Cohen's Kappa: 0.4162
# Log Loss: 0.4576
# ROC AUC Score: 0.8214
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.75      0.43      0.55         7
#            1       0.79      0.94      0.86        16
#
#     accuracy                           0.78        23
#    macro avg       0.77      0.68      0.70        23
# weighted avg       0.78      0.78      0.76        23
#
#
# ================== BEST RANDOM STATE ==================
#
# Best Random State: 8
# Validation Accuracy: 1.0000
# Balanced Accuracy: 1.0000
# Cohen's Kappa: 1.0000
# Log Loss: 0.1567
# ROC AUC Score: 1.0000
#
# ========================================================

# %%
import pandas as pd

data = pd.read_csv("random_state_results_mdd3_80.csv")

# %%
import pandas as pd

# import pandas as pd
import numpy as np
def create_model_quality_features(df):
    """
    Enhances a DataFrame containing model evaluation metrics by generating new, meaningful features
    and diagnostic flags to assess performance, stability, overfitting, and class imbalance.

    Expected columns: 'accuracy', 'balanced_accuracy', 'kappa', 'log_loss', 'roc_auc'
    """

    df = df.copy()

    # Basic calculated metrics
    df['harmonic_acc'] = 2 * (df['accuracy'] * df['balanced_accuracy']) / (
        df['accuracy'] + df['balanced_accuracy'] + 1e-8)

    df['kappa_acc_ratio'] = df['kappa'] / (df['accuracy'] + 1e-8)
    df['inv_log_loss'] = 1 / (df['log_loss'] + 1e-8)

    # Normalized ROC AUC
    roc_min = df['roc_auc'].min()
    roc_max = df['roc_auc'].max()
    df['roc_auc_norm'] = (df['roc_auc'] - roc_min) / (roc_max - roc_min + 1e-8)

    # Composite score (weighted performance summary)
    df['composite_score'] = (
        0.25 * df['accuracy'] +
        0.25 * df['balanced_accuracy'] +
        0.2 * df['roc_auc_norm'] +
        0.15 * df['kappa'] +
        0.15 * df['inv_log_loss']
    )

    # Overfitting detection:
    # High accuracy with either low generalization (kappa), very low log loss (overconfidence),
    # or large imbalance gap between accuracy and balanced accuracy
    df['overfitting_flag'] = (
        (df['accuracy'] >= 0.99) &
        (
            (df['kappa'] < 0.5) |
            (df['log_loss'] < 0.2) |
            ((df['accuracy'] - df['balanced_accuracy']) > 0.2)
        )
    )

    # Class imbalance signal: accuracy is much higher than balanced accuracy
    df['imbalance_signal'] = (df['accuracy'] - df['balanced_accuracy']) > 0.15

    # Overconfident model: suspiciously low log loss
    df['overconfident_model'] = df['log_loss'] < 0.5

    # Stability index: combines kappa and ROC AUC (higher = more stable/generalizable)
    df['stability_index'] = (df['kappa'] + df['roc_auc']) / 2

    # Error-to-confidence ratio: how much uncertainty (log loss) relative to classifier strength
    df['error_confidence_ratio'] = df['log_loss'] / (1 - df['roc_auc'] + 1e-8)

    return df

df = pd.read_csv("random_state_results_mdd2_mdd3_variants.csv")

df_with_features = create_model_quality_features(df)
df_with_features.to_csv("random_state_results_mdd_all_datasizes.csv", index=False)
